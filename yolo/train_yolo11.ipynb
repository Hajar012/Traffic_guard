# %% [markdown]
# **Upload Yolo11 & Train**

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")
model.train(data="data.yaml", epochs=50, imgsz=640, batch=8, device=0, workers=2, optimizer="AdamW", lr0=0.001, weight_decay=0.0005, patience=20, mosaic=0.5, fliplr=0.5, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4)
# results_dict: {'metrics/precision(B)': 0.864504206801439,
#                'metrics/recall(B)': 0.8814280328817179,
#                'metrics/mAP50(B)': 0.9324222301591614,
#                'metrics/mAP50-95(B)': 0.77479286858052,
#                'fitness': 0.77479286858052}

# %% [markdown]
# **Test Model**

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train2/weights/best.pt")
model.predict("test/yellowTruck.jpg", show=True, save=True)

# %%
from ultralytics import YOLO
import cv2

model = YOLO("runs/detect/train2/weights/best.pt")

cap = cv2.VideoCapture("test/carsAtDay.mp4")

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)

    annotated_frame = results[0].plot()

    cv2.imshow("YOLOv11 Detection", annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()

# %%
print("test")
# Out:
# test
